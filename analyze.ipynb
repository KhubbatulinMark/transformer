# %%
import os
import glob
import pandas as pd

import tools
import warnings
warnings.simplefilter("ignore", UserWarning)

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data = tools.get_all_data('row_data', 'txt')

# %%
data.head(5)
# Out:
#          H2        CO      C2H4      C2H2 status            datetime
# 0  0.000224  0.000862  0.000000  0.000000    LTO 2020-01-01 00:00:00
# 1  0.000900  0.000848  0.000900  0.000022    LTO 2020-01-01 12:00:00
# 2  0.000000  0.000902  0.000045  0.000000    LTO 2020-01-02 00:00:00
# 3  0.000470  0.001153  0.000448  0.000000    LTO 2020-01-02 12:00:00
# 4  0.000065  0.000996  0.000005  0.000000    LTO 2020-01-03 00:00:00

# %% [markdown]
# # Количество отсчетов

# %%
fig, ax = plt.subplots()
fig.set_size_inches(21, 9)
ax = sns.countplot(x="status", data=data)

# %%
sns.pairplot(data, hue="status", height=2.5, aspect=1.5);

# %% [markdown]
# # Распределения концентрации газов

# %%
sns.displot(data, x="H2", hue="status", kind="kde", fill=True, height=7, aspect=3)
plt.show();

# %%
sns.displot(data, x="CO", hue="status", kind="kde", fill=True, height=7, aspect=3)
plt.show();

# %%
sns.displot(data, x="C2H4", hue="status", kind="kde", fill=True, height=7, aspect=3)
plt.show();

# %%
sns.displot(data, x="C2H2", hue="status", kind="kde", fill=True, height=7, aspect=3)
plt.show();

# %%
data_lto = data[data['status'] == 'LTO']
data_pd = data[data['status'] == 'PD']
data_led = data[data['status'] == 'LED']
data_normal = data[data['status'] == 'norm']

# %%
status = ['H2', 'C2H2', 'CO', 'C2H4']
for i in status:
    g = sns.relplot(
        x="datetime", y=i, data=data_pd,
        kind="line", ci=None, height=7, aspect=3)
    g.fig.suptitle(f'Временной ряд концентрации {i} при Частичном разряде');
